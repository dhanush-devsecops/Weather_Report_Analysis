# %% [markdown]
# # Weather EDA
#
# This notebook contains an initial exploration of the Telangana weather dataset.

# %%
import pandas as pd
from pathlib import Path

data_path = Path('..') / 'data' / 'Telangana_combined_weather_data.csv'
df = pd.read_csv(data_path)
df.head()
